# %%
import torch
from torch.utils.data import DataLoader, Dataset
from transformers import RobertaTokenizer, RobertaForSequenceClassification, AdamW
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, confusion_matrix
import pandas as pd
import numpy as np
from tqdm import tqdm
import random
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
# Loading the Excel file
df = pd.read_excel('negative_sentiments.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User           209 non-null    object
#  1   Tweet          209 non-null    object
#  2   Cleaned_Tweet  209 non-null    object
#  3   Negative       209 non-null    float64
#  4   Neutral        209 non-null    float64
#  5   Positive       209 non-null    float64
#  6   Sentiment      209 non-null    object
#  7   Label          151 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 13.2+ KB

# %%
predict_df = df[df['Label'].isna()]

# %%
predict_df
# Out:
#                                             User  \
# 151                                          Bev
# 152                                      Nigel 💙
# 153                                      Nigel 💙
# 154                           Iain Joseph Gorry*
# 155              North East Lincolnshire Council
# 156                         South Yorkshire Fire
# 157  Humberside Police - North East Lincolnshire
# 158                           Safer Roads Humber
# 159                          North Lincs Council
# 160                                    DC_LK1989
# 161                        Alan Clark 💙 🇺🇦 🇪🇺 🇬🇧
# 162                  Park Street Performing Arts
# 163                 Lincolnshire Fire and Rescue
# 164                                      russell
# 165                                    Mark Webb
# 166                             James Mitchinson
# 167                                  Bog-trotter
# 168                                          CSB
# 169                                   Rob Buckle
# 170                      Sheffield Environmental
# 171                                  Bog-trotter
# 172                                 chris spavin
# 173                                 Guy Hitchins
# 174                                Hull 4 Heroes
# 175                               Farmers Weekly
# 176                          PCSO Darren Bainton
# 177                                  Dave Nassau
# 178                                     Debs B 🌱
# 179     Elephant in The Room Disability Services
# 180                              RSPCA Frontline
# 181                                Howard Davies
# 182                                        Jon T
# 183                           Jazzmariner ⚫️⚪️😁👏
# 184                                Lankyshirelad
# 185                               Phillip Norton
# 186                                   Kev Taylor
# 187                                Phil Shillito
# 188                              Adam Tunningley
# 189                                          CDW
# 190                                mollie brooks
# 191                                 Andy Creasey
# 192                               Peter Anderson
# 193          Nickynoo/Aquanaught/conservationist
# 194                                 Kevin Childs
# 195                                         Nick
# 196    East Midlands Ambulance Service NHS Trust
# 197                                 Gareth smith
# 198   Greatest Hits Radio York & North Yorkshire
# 199                               Phillip Norton
# 200                        UK Fire Rescue Photos
# 201                                       Stew B
# 202               Adam Craig, PB (Xe/Xer/Xerxes)
# 203                         St Richard's Academy
# 204                            Wolds View Garage
# 205                           Susan Chandler 💙🇺🇦
# 206                              caroline bilton
# 207                              Hull Flood Risk
# 208                    Miriam Heppell 💙MSc FCIPD
#
#                                                  Tweet  \
# 151  @GyAncient @nige_gallop @CCLeeFreeman @Cleeccs...
# 152  @GyAncient @BevskiMids @CCLeeFreeman @Cleeccsc...
# 153  @BevskiMids @CCLeeFreeman @Cleeccsc @Humberbea...
# 154  @Cleeccsc @JoRobbo68 @Humberbeat @HumbersideFi...
# 155  What are the biggest crime issues in North Eas...
# 156  We spent weeks tackling a fire on Hatfield Moo...
# 157  #Grimsby #Willows Attended an incident tonight...
# 158  A fire safety message today. With more people ...
# 159  Just because it's warm outside, it doesn't mea...
# 160  Unfortunately I’m going to say no...our street...
# 161  @Fionamills1 @Humber_01 @HareWolfy @LouiseWrit...
# 162  @HareWolfy @Humber_01 @Fionamills1 @LouiseWrit...
# 163  13:26 1/2 Wholetime and On-Call Crew from @Gai...
# 164  @HumbersideFire Glad no one injured 👍 i have b...
# 165  @CFOBlacksell @HumbersideFire @Humberbeat This...
# 166  @CFOBlacksell @HumbersideFire @Humberbeat Well...
# 167  @Marktur03393381 @SYFR @WYFRS @LancashireFRS @...
# 168  @PCSODarrenB @HumbersideFire Over the limit? N...
# 169  @sunkfarmer @PCSODarrenB @HumbersideFire Misse...
# 170  @BryonyHolroyd @AndyMbirder @4peatssake2 @Wint...
# 171  @paulbrear @HumbersideFire @SYFR Today (30 May...
# 172  @HumbersideFire Hi sorry to both you. Just won...
# 173  @HumbersideFire @SYFR Sooo much of this going ...
# 174  Five families had their lives turned upside do...
# 175  Top marks @HumbersideFire 👍 Sky lanterns start...
# 176  Please avoid using #SkyLanterns when showing y...
# 177  @Dr_Dan_1 @HumbersideFire @ChrisGPackham @Bell...
# 178  @BBCLookNorth @HumbersideFire Emergency servic...
# 179  @CEXHCC @21_hardy @Hullccnews @NHSHullCCG @NHS...
# 180  Thank you to @HumbersideFire for assisting Ins...
# 181  @shooter724 @Humberbeat @HumbersideFire The no...
# 182  The CPAD at #Patrington fire station is now ba...
# 183  @JKH62 @EnvAgencyYNE @johncurtinEA @EnvAgency ...
# 184  @EnvAgencyYNE @johncurtinEA @EnvAgency @TobyWi...
# 185  A public meeting is taking place at Snaith Pri...
# 186  250,000 litres of flood waters pumped away eve...
# 187  The rain might have stopped but the multi agen...
# 188  Media duties in #Snaith for me this morning. A...
# 189  @HumbersideFire And the winners of the worst j...
# 190  @EllieSimmonds1 @HumbersideFire Apparently thi...
# 191  Again people refuse the listen or act on warni...
# 192  @krispygreen84 @HumbersideFire @officialgtfc I...
# 193  Today after a trip around the reserve I found ...
# 194  @NELCouncil @HumberbeatNEL @HumbersideFire Be ...
# 195  @CCLeeFreeman @Humberbeat @HumbersideFire @EMA...
# 196  Our General Manager for Lincolnshire, Sue Cous...
# 197  @BrocklesbyLtd @HumbersideFire Devastating new...
# 198  NEWS - Huge vegetable oil fire in East Yorkshi...
# 199  The A180 is closed eastbound from Barnetby Top...
# 200  @Ball01B @HumbersideFire They looked terrible ...
# 201  @fireenguk @HumbersideFire Those Volvos were t...
# 202  @UniofHull @HullPoliticsDep employee, Justin M...
# 203  Making children more aware about domestic abus...
# 204  @HumbersideFire North Cave beck had burst it's...
# 205  @CoultishNick @21_hardy @HumberbeatRoads @Radi...
# 206  Main slip road off A1079 into Beverley closed ...
# 207  Hopefully today's rain will not cause us more ...
# 208  Startling statistics from Simon Gallow, Develo...
#
#                                          Cleaned_Tweet  Negative   Neutral  \
# 151  bagger amazed knew walking football result yes...  0.519025  0.442044
# 152                                blimey mick old dog  0.677478  0.285934
# 153  wondered rd right obvs due play rare midweek g...  0.763980  0.222234
# 154                         guy tweet date wrong think  0.664363  0.322601
# 155  biggest crime issue north east lincolnshire te...  0.662119  0.320535
# 156  spent week tackling fire hatfield moor despera...  0.560314  0.336407
# 157  attended incident tonight binbrook way group y...  0.889538  0.104743
# 158  fire safety message today people easy overload...  0.514286  0.462393
# 159  warm outside doesnt mean warm underwater cold ...  0.698401  0.289254
# 160  unfortunately im going say noour street would ...  0.875694  0.117654
# 161         didnt think would put outfit last incident  0.504043  0.470565
# 162     sliding batpole must fraught pain danger wolfy  0.644666  0.341539
# 163  wholetime oncall crew appliance misterton amp ...  0.538386  0.443323
# 164  glad one injured back work week realise mad li...  0.590768  0.373226
# 165  lazy gutterpress journalism embarrassment wors...  0.962897  0.034687
# 166  well said chris sorry medium making job difficult  0.747294  0.234820
# 167  day sequestration capacity lost c acre sssi na...  0.723867  0.256126
# 168                           limit sympathy im afraid  0.808927  0.180259
# 169                          missed wall end inch look  0.510658  0.459784
# 170  grazers would eaten low braches still place li...  0.612657  0.372969
# 171  today may day amp day use helicopter show seri...  0.852878  0.140245
# 172  hi sorry wondered letter posted mum letter box...  0.871667  0.120409
# 173  sooo much going present avoidable sadly helico...  0.521803  0.400316
# 174  five family life turned upside arsonist hull i...  0.766391  0.223161
# 175  top mark sky lantern start fire deadly farm an...  0.744505  0.243972
# 176  please avoid using showing appreciation nh amp...  0.772356  0.217180
# 177  please please please please dont set sky lante...  0.963210  0.034221
# 178  emergency service enough dealing earth lantern...  0.686192  0.303560
# 179  also dedicated email cant use phone deaf non v...  0.709626  0.275995
# 180  thank assisting insp hutton evening bridlingto...  0.771515  0.213819
# 181                             nose know fooling etta  0.486248  0.454826
# 182  cpad fire station back running ive replaced un...  0.531859  0.422922
# 183  presumably dont agree science dredging would m...  0.492322  0.480894
# 184                 dredging sediment crap river start  0.892963  0.099527
# 185  public meeting taking place snaith primary sch...  0.593255  0.390547
# 186  litre flood water pumped away every minute sti...  0.792955  0.188807
# 187  rain might stopped multi agency response affec...  0.737688  0.253263
# 188  medium duty morning awful see home flooded des...  0.742428  0.229025
# 189                             winner worst joke year  0.918154  0.067271
# 190  apparently fake grown adult pretending he post...  0.933319  0.063430
# 191  people refuse listen act warning obvious sign ...  0.629452  0.352369
# 192                                          lucky get  0.648431  0.286872
# 193  today trip around reserve found call could wit...  0.536601  0.427751
# 194  nice thing around ward east west marsh problem...  0.637865  0.300916
# 195  emergency worker assaulted must full extent la...  0.636483  0.352187
# 196  general manager lincolnshire sue cousland morn...  0.912067  0.084404
# 197  devastating news sorry rob everyone involved b...  0.497504  0.348119
# 198    news huge vegetable oil fire east yorkshire pic  0.544575  0.433751
# 199  closed eastbound barnetby top brocklesby inter...  0.503025  0.480293
# 200  looked terrible aswell fair think snaith one m...  0.856355  0.134946
# 201  volvos terrible two lgv training slow get mph ...  0.617543  0.356642
# 202  employee justin morris stalker harasser instig...  0.963156  0.034609
# 203                  making child aware domestic abuse  0.528476  0.457157
# 204  north cave beck burst bank footpath bridge pap...  0.592032  0.395054
# 205                                      heartbreaking  0.818087  0.161149
# 206  main slip road beverley closed due flooding ho...  0.658541  0.328864
# 207  hopefully today rain cause u problem remember ...  0.540422  0.419639
# 208  startling statistic simon gallow development d...  0.772055  0.218688
#
#      Positive Sentiment  Label
# 151  0.038931  negative    NaN
# 152  0.036588  negative    NaN
# 153  0.013785  negative    NaN
# 154  0.013036  negative    NaN
# 155  0.017346  negative    NaN
# 156  0.103279  negative    NaN
# 157  0.005718  negative    NaN
# 158  0.023321  negative    NaN
# 159  0.012345  negative    NaN
# 160  0.006652  negative    NaN
# 161  0.025392  negative    NaN
# 162  0.013795  negative    NaN
# 163  0.018291  negative    NaN
# 164  0.036006  negative    NaN
# 165  0.002416  negative    NaN
# 166  0.017886  negative    NaN
# 167  0.020007  negative    NaN
# 168  0.010814  negative    NaN
# 169  0.029558  negative    NaN
# 170  0.014374  negative    NaN
# 171  0.006877  negative    NaN
# 172  0.007924  negative    NaN
# 173  0.077880  negative    NaN
# 174  0.010447  negative    NaN
# 175  0.011523  negative    NaN
# 176  0.010464  negative    NaN
# 177  0.002569  negative    NaN
# 178  0.010248  negative    NaN
# 179  0.014379  negative    NaN
# 180  0.014666  negative    NaN
# 181  0.058925  negative    NaN
# 182  0.045219  negative    NaN
# 183  0.026784  negative    NaN
# 184  0.007510  negative    NaN
# 185  0.016198  negative    NaN
# 186  0.018238  negative    NaN
# 187  0.009050  negative    NaN
# 188  0.028548  negative    NaN
# 189  0.014574  negative    NaN
# 190  0.003251  negative    NaN
# 191  0.018179  negative    NaN
# 192  0.064697  negative    NaN
# 193  0.035647  negative    NaN
# 194  0.061219  negative    NaN
# 195  0.011330  negative    NaN
# 196  0.003528  negative    NaN
# 197  0.154377  negative    NaN
# 198  0.021675  negative    NaN
# 199  0.016683  negative    NaN
# 200  0.008699  negative    NaN
# 201  0.025815  negative    NaN
# 202  0.002236  negative    NaN
# 203  0.014367  negative    NaN
# 204  0.012914  negative    NaN
# 205  0.020764  negative    NaN
# 206  0.012595  negative    NaN
# 207  0.039939  negative    NaN
# 208  0.009258  negative    NaN

# %%
train_df = df.dropna(subset=['Label'])

# %%
train_df
# Out:
#                                                   User  \
# 0                                     Phillip Marshall
# 1                                            @KateHull
# 2                                   Abigail Wainwright
# 3                                        Phil Shillito
# 4                                          Radhotchoco
# ..                                                 ...
# 146                                     Phillip Norton
# 147                                     Theresa Capper
# 148                                                CDW
# 149                                                CDW
# 150  The Carer's Information and Support Service, Hull
#
#                                                  Tweet  \
# 0    @HumbersideFire No mention of headlights. Disa...
# 1    Yet another historic, #grade2listed #church up...
# 2    @davidthomas4085 @HumbersideFire @East_Riding ...
# 3    @cllrmikeross Sad news and Mark will be missed...
# 4    @HumbersideFire part of building at Atom bar, ...
# ..                                                 ...
# 146  The fire at Haltemprice Crematorium is now out...
# 147  @HumbersideFire Great punishment....NOT!!! 🤬 s...
# 148  @simonpheadley @Stef_Walton @HumbersideFire Th...
# 149  @HumbersideFire Guess this has gotten worse fr...
# 150  @HumbersideFire needs your help #safeandwell #...
#
#                                          Cleaned_Tweet  Negative   Neutral  \
# 0                      mention headlight disappointing  0.909523  0.084315
# 1    yet another historic flame cost u heritage imp...  0.890281  0.105682
# 2    working hour shame drain cranswick seem poorly...  0.947041  0.049033
# 3          sad news mark missed many condolence family  0.789475  0.187370
# 4    part building atom bar princess avenue upstair...  0.730137  0.260935
# ..                                                 ...       ...       ...
# 146  fire haltemprice crematorium operator cremator...  0.628737  0.359705
# 147  great punishmentnot shame couldnt turn hose jo...  0.562310  0.319152
# 148  fact command unit aerial attendance saying wor...  0.775761  0.213087
# 149        guess gotten worse smoke issuing major fire  0.840872  0.149536
# 150                                          need help  0.534867  0.418089
#
#      Positive Sentiment  Label
# 0    0.006161  negative    0.0
# 1    0.004037  negative    1.0
# 2    0.003926  negative    1.0
# 3    0.023155  negative    0.0
# 4    0.008928  negative    1.0
# ..        ...       ...    ...
# 146  0.011559  negative    0.0
# 147  0.118538  negative    0.0
# 148  0.011153  negative    0.0
# 149  0.009592  negative    1.0
# 150  0.047044  negative    1.0
#
# [151 rows x 8 columns]

# %%
train_df['Label'].value_counts()
# Out:
# Label
# 0.0    118
# 1.0     33
# Name: count, dtype: int64

# %% [markdown]
# # RoBERTa Model

# %%
# Tokenizer and model
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
model = RobertaForSequenceClassification.from_pretrained('roberta-base', num_labels=2)
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Tokenizing and preparing DataLoader for training
class CustomDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = str(self.texts[idx])

        label = 0 if self.labels is None else int(self.labels[idx])

        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt',
        )
        return {
            'text': text,
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'label': torch.tensor(label, dtype=torch.long)
        }

# %%
# Splitting the training data for RoBERTa
train_texts, val_texts, train_labels, val_labels = train_test_split(
    train_df['Cleaned_Tweet'].values,
    train_df['Label'].values,
    test_size=0.1,
    random_state=42
)

# %%
# Creating datasets and DataLoader for training
train_dataset = CustomDataset(train_texts, train_labels, tokenizer)
val_dataset = CustomDataset(val_texts, val_labels, tokenizer)

# %%
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)

# %%
# Training the RoBERTa 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
epochs = 100

best_val_loss = float('inf')
patience = 7 
counter = 0

for epoch in range(epochs):
    # Training loop
    model.train()
    for batch in tqdm(train_loader, desc=f"Epoch {epoch}"):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)

        optimizer.zero_grad()

        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        loss.backward()

        optimizer.step()

    # Validation loop
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for batch in tqdm(val_loader, desc="Validation"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask)
            logits = outputs.logits
            preds = torch.argmax(logits, dim=1)
            loss = torch.nn.functional.cross_entropy(logits, labels)

            val_loss += loss.item()

    # Calculating average validation loss
    avg_val_loss = val_loss / len(val_loader)

    # Checking for early stopping
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        counter = 0
    else:
        counter += 1

    if counter >= patience:
        print(f'Early stopping after {epoch + 1} epochs without improvement.')
        break
# Out:
# Epoch 0: 100%|█████████████████████████████████████████████████████████████████████████| 17/17 [00:07<00:00,  2.36it/s]
# Validation: 100%|████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.92it/s]
# Epoch 1: 100%|█████████████████████████████████████████████████████████████████████████| 17/17 [00:05<00:00,  2.92it/s]
# Validation: 100%|████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  4.06it/s]
# Epoch 2: 100%|█████████████████████████████████████████████████████████████████████████| 17/17 [00:05<00:00,  2.91it/s]
# Validation: 100%|████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.87it/s]
# Epoch 3: 100%|█████████████████████████████████████████████████████████████████████████| 17/17 [00:05<00:00,  2.91it/s]
# Validation: 100%|████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.87it/s]
# Epoch 4: 100%|█████████████████████████████████████████████████████████████████████████| 17/17 [00:05<00:00,  2.91it/s]
# Validation: 100%|████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.88it/s]
# Epoch 5: 100%|█████████████████████████████████████████████████████████████████████████| 17/17 [00:05<00:00,  2.91it/s]
# Validation: 100%|████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.87it/s]
# Epoch 6: 100%|█████████████████████████████████████████████████████████████████████████| 17/17 [00:05<00:00,  2.91it/s]
# Validation: 100%|████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.86it/s]
# Epoch 7: 100%|█████████████████████████████████████████████████████████████████████████| 17/17 [00:05<00:00,  2.91it/s]
# Validation: 100%|████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.88it/s]
# Epoch 8: 100%|█████████████████████████████████████████████████████████████████████████| 17/17 [00:05<00:00,  2.91it/s]
# Validation: 100%|████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.88it/s]
# Epoch 9: 100%|█████████████████████████████████████████████████████████████████████████| 17/17 [00:05<00:00,  2.91it/s]
# Validation: 100%|████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.90it/s]
# Epoch 10: 100%|████████████████████████████████████████████████████████████████████████| 17/17 [00:05<00:00,  2.91it/s]
# Validation: 100%|████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.90it/s]
# Epoch 11: 100%|████████████████████████████████████████████████████████████████████████| 17/17 [00:05<00:00,  2.91it/s]
# Validation: 100%|████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.82it/s]
# Epoch 12: 100%|████████████████████████████████████████████████████████████████████████| 17/17 [00:05<00:00,  2.90it/s]
# Validation: 100%|████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  3.93it/s]
# Early stopping after 13 epochs without improvement.

# %%
# Validation
model.eval()
val_preds = []
val_true = []

with torch.no_grad():
    for batch in tqdm(val_loader, desc="Validation"):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)

        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        preds = torch.argmax(logits, dim=1)

        val_preds.extend(preds.cpu().numpy())
        val_true.extend(labels.cpu().numpy())

print(classification_report(val_true, val_preds))
# Out:
# Validation: 100%|████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  7.75it/s]
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        15
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.94        16
#    macro avg       0.47      0.50      0.48        16
# weighted avg       0.88      0.94      0.91        16
# C:\Users\Amro\anaconda3\envs\gpu2\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Amro\anaconda3\envs\gpu2\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Amro\anaconda3\envs\gpu2\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Calculating Mean Squared Error (MSE)
mse = mean_squared_error(val_true, val_preds)
print(f"Mean Squared Error (MSE): {mse:.4f}")

# Calculating Mean Absolute Error (MAE)
mae = mean_absolute_error(val_true, val_preds)
print(f"Mean Absolute Error (MAE): {mae:.4f}")

# Calculating R-squared (R2) score
r2 = r2_score(val_true, val_preds)
print(f"R-squared (R2) Score: {r2:.4f}")
# Out:
# Mean Squared Error (MSE): 0.0625
# Mean Absolute Error (MAE): 0.0625
# R-squared (R2) Score: -0.0667

# %% [markdown]
# ### Prediction of RoBERTa model on Tweets

# %%
# loading file with data for prediction
new_df = pd.read_excel('Labeled_Tweets.xlsx')

# %%
# Assuming 'Cleaned_Tweet' is the column containing the text data for prediction
new_texts = new_df['Cleaned_Tweet'].values

# Tokenize and prepare DataLoader for prediction
new_dataset = CustomDataset(new_texts, labels=None, tokenizer=tokenizer, max_len=128)
new_loader = DataLoader(new_dataset, batch_size=8, shuffle=False, collate_fn=lambda x: x)

# Make predictions
model.eval()
predictions = []

with torch.no_grad():
    for batch in tqdm(new_loader, desc="Predicting"):
        input_ids = torch.stack([item['input_ids'] for item in batch]).to(device)
        attention_mask = torch.stack([item['attention_mask'] for item in batch]).to(device)

        outputs = model(input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        preds = torch.argmax(logits, dim=1)

        predictions.extend(preds.cpu().numpy())
# Out:
# Predicting: 100%|████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00,  8.47it/s]

# %%
# Adding predictions to the DataFrame
new_df['RoBERTa_Prediction'] = predictions

# %%
new_df
# Out:
#                                            User  \
# 0                                           Bev
# 1                                       Nigel 💙
# 2                                       Nigel 💙
# 3                            Iain Joseph Gorry*
# 4               North East Lincolnshire Council
# 5                          South Yorkshire Fire
# 6   Humberside Police - North East Lincolnshire
# 7                            Safer Roads Humber
# 8                           North Lincs Council
# 9                                     DC_LK1989
# 10                        Alan Clark 💙 🇺🇦 🇪🇺 🇬🇧
# 11                  Park Street Performing Arts
# 12                 Lincolnshire Fire and Rescue
# 13                                      russell
# 14                                    Mark Webb
# 15                             James Mitchinson
# 16                                  Bog-trotter
# 17                                          CSB
# 18                                   Rob Buckle
# 19                      Sheffield Environmental
# 20                                  Bog-trotter
# 21                                 chris spavin
# 22                                 Guy Hitchins
# 23                                Hull 4 Heroes
# 24                               Farmers Weekly
# 25                          PCSO Darren Bainton
# 26                                  Dave Nassau
# 27                                     Debs B 🌱
# 28     Elephant in The Room Disability Services
# 29                              RSPCA Frontline
# 30                                Howard Davies
# 31                                        Jon T
# 32                           Jazzmariner ⚫️⚪️😁👏
# 33                                Lankyshirelad
# 34                               Phillip Norton
# 35                                   Kev Taylor
# 36                                Phil Shillito
# 37                              Adam Tunningley
# 38                                          CDW
# 39                                mollie brooks
# 40                                 Andy Creasey
# 41                               Peter Anderson
# 42          Nickynoo/Aquanaught/conservationist
# 43                                 Kevin Childs
# 44                                         Nick
# 45    East Midlands Ambulance Service NHS Trust
# 46                                 Gareth smith
# 47   Greatest Hits Radio York & North Yorkshire
# 48                               Phillip Norton
# 49                        UK Fire Rescue Photos
# 50                                       Stew B
# 51               Adam Craig, PB (Xe/Xer/Xerxes)
# 52                         St Richard's Academy
# 53                            Wolds View Garage
# 54                           Susan Chandler 💙🇺🇦
# 55                              caroline bilton
# 56                              Hull Flood Risk
# 57                    Miriam Heppell 💙MSc FCIPD
#
#                                                 Tweet  \
# 0   @GyAncient @nige_gallop @CCLeeFreeman @Cleeccs...
# 1   @GyAncient @BevskiMids @CCLeeFreeman @Cleeccsc...
# 2   @BevskiMids @CCLeeFreeman @Cleeccsc @Humberbea...
# 3   @Cleeccsc @JoRobbo68 @Humberbeat @HumbersideFi...
# 4   What are the biggest crime issues in North Eas...
# 5   We spent weeks tackling a fire on Hatfield Moo...
# 6   #Grimsby #Willows Attended an incident tonight...
# 7   A fire safety message today. With more people ...
# 8   Just because it's warm outside, it doesn't mea...
# 9   Unfortunately I’m going to say no...our street...
# 10  @Fionamills1 @Humber_01 @HareWolfy @LouiseWrit...
# 11  @HareWolfy @Humber_01 @Fionamills1 @LouiseWrit...
# 12  13:26 1/2 Wholetime and On-Call Crew from @Gai...
# 13  @HumbersideFire Glad no one injured 👍 i have b...
# 14  @CFOBlacksell @HumbersideFire @Humberbeat This...
# 15  @CFOBlacksell @HumbersideFire @Humberbeat Well...
# 16  @Marktur03393381 @SYFR @WYFRS @LancashireFRS @...
# 17  @PCSODarrenB @HumbersideFire Over the limit? N...
# 18  @sunkfarmer @PCSODarrenB @HumbersideFire Misse...
# 19  @BryonyHolroyd @AndyMbirder @4peatssake2 @Wint...
# 20  @paulbrear @HumbersideFire @SYFR Today (30 May...
# 21  @HumbersideFire Hi sorry to both you. Just won...
# 22  @HumbersideFire @SYFR Sooo much of this going ...
# 23  Five families had their lives turned upside do...
# 24  Top marks @HumbersideFire 👍 Sky lanterns start...
# 25  Please avoid using #SkyLanterns when showing y...
# 26  @Dr_Dan_1 @HumbersideFire @ChrisGPackham @Bell...
# 27  @BBCLookNorth @HumbersideFire Emergency servic...
# 28  @CEXHCC @21_hardy @Hullccnews @NHSHullCCG @NHS...
# 29  Thank you to @HumbersideFire for assisting Ins...
# 30  @shooter724 @Humberbeat @HumbersideFire The no...
# 31  The CPAD at #Patrington fire station is now ba...
# 32  @JKH62 @EnvAgencyYNE @johncurtinEA @EnvAgency ...
# 33  @EnvAgencyYNE @johncurtinEA @EnvAgency @TobyWi...
# 34  A public meeting is taking place at Snaith Pri...
# 35  250,000 litres of flood waters pumped away eve...
# 36  The rain might have stopped but the multi agen...
# 37  Media duties in #Snaith for me this morning. A...
# 38  @HumbersideFire And the winners of the worst j...
# 39  @EllieSimmonds1 @HumbersideFire Apparently thi...
# 40  Again people refuse the listen or act on warni...
# 41  @krispygreen84 @HumbersideFire @officialgtfc I...
# 42  Today after a trip around the reserve I found ...
# 43  @NELCouncil @HumberbeatNEL @HumbersideFire Be ...
# 44  @CCLeeFreeman @Humberbeat @HumbersideFire @EMA...
# 45  Our General Manager for Lincolnshire, Sue Cous...
# 46  @BrocklesbyLtd @HumbersideFire Devastating new...
# 47  NEWS - Huge vegetable oil fire in East Yorkshi...
# 48  The A180 is closed eastbound from Barnetby Top...
# 49  @Ball01B @HumbersideFire They looked terrible ...
# 50  @fireenguk @HumbersideFire Those Volvos were t...
# 51  @UniofHull @HullPoliticsDep employee, Justin M...
# 52  Making children more aware about domestic abus...
# 53  @HumbersideFire North Cave beck had burst it's...
# 54  @CoultishNick @21_hardy @HumberbeatRoads @Radi...
# 55  Main slip road off A1079 into Beverley closed ...
# 56  Hopefully today's rain will not cause us more ...
# 57  Startling statistics from Simon Gallow, Develo...
#
#                                         Cleaned_Tweet  Negative   Neutral  \
# 0   bagger amazed knew walking football result yes...  0.519025  0.442044
# 1                                 blimey mick old dog  0.677478  0.285934
# 2   wondered rd right obvs due play rare midweek g...  0.763980  0.222234
# 3                          guy tweet date wrong think  0.664363  0.322601
# 4   biggest crime issue north east lincolnshire te...  0.662119  0.320535
# 5   spent week tackling fire hatfield moor despera...  0.560314  0.336407
# 6   attended incident tonight binbrook way group y...  0.889538  0.104743
# 7   fire safety message today people easy overload...  0.514286  0.462393
# 8   warm outside doesnt mean warm underwater cold ...  0.698401  0.289254
# 9   unfortunately im going say noour street would ...  0.875694  0.117654
# 10         didnt think would put outfit last incident  0.504043  0.470565
# 11     sliding batpole must fraught pain danger wolfy  0.644666  0.341539
# 12  wholetime oncall crew appliance misterton amp ...  0.538386  0.443323
# 13  glad one injured back work week realise mad li...  0.590768  0.373226
# 14  lazy gutterpress journalism embarrassment wors...  0.962897  0.034687
# 15  well said chris sorry medium making job difficult  0.747294  0.234820
# 16  day sequestration capacity lost c acre sssi na...  0.723867  0.256126
# 17                           limit sympathy im afraid  0.808927  0.180259
# 18                          missed wall end inch look  0.510658  0.459784
# 19  grazers would eaten low braches still place li...  0.612657  0.372969
# 20  today may day amp day use helicopter show seri...  0.852878  0.140245
# 21  hi sorry wondered letter posted mum letter box...  0.871667  0.120409
# 22  sooo much going present avoidable sadly helico...  0.521803  0.400316
# 23  five family life turned upside arsonist hull i...  0.766391  0.223161
# 24  top mark sky lantern start fire deadly farm an...  0.744505  0.243972
# 25  please avoid using showing appreciation nh amp...  0.772356  0.217180
# 26  please please please please dont set sky lante...  0.963210  0.034221
# 27  emergency service enough dealing earth lantern...  0.686192  0.303560
# 28  also dedicated email cant use phone deaf non v...  0.709626  0.275995
# 29  thank assisting insp hutton evening bridlingto...  0.771515  0.213819
# 30                             nose know fooling etta  0.486248  0.454826
# 31  cpad fire station back running ive replaced un...  0.531859  0.422922
# 32  presumably dont agree science dredging would m...  0.492322  0.480894
# 33                 dredging sediment crap river start  0.892963  0.099527
# 34  public meeting taking place snaith primary sch...  0.593255  0.390547
# 35  litre flood water pumped away every minute sti...  0.792955  0.188807
# 36  rain might stopped multi agency response affec...  0.737688  0.253263
# 37  medium duty morning awful see home flooded des...  0.742428  0.229025
# 38                             winner worst joke year  0.918154  0.067271
# 39  apparently fake grown adult pretending he post...  0.933319  0.063430
# 40  people refuse listen act warning obvious sign ...  0.629452  0.352369
# 41                                          lucky get  0.648431  0.286872
# 42  today trip around reserve found call could wit...  0.536601  0.427751
# 43  nice thing around ward east west marsh problem...  0.637865  0.300916
# 44  emergency worker assaulted must full extent la...  0.636483  0.352187
# 45  general manager lincolnshire sue cousland morn...  0.912067  0.084404
# 46  devastating news sorry rob everyone involved b...  0.497504  0.348119
# 47    news huge vegetable oil fire east yorkshire pic  0.544575  0.433751
# 48  closed eastbound barnetby top brocklesby inter...  0.503025  0.480293
# 49  looked terrible aswell fair think snaith one m...  0.856355  0.134946
# 50  volvos terrible two lgv training slow get mph ...  0.617543  0.356642
# 51  employee justin morris stalker harasser instig...  0.963156  0.034609
# 52                  making child aware domestic abuse  0.528476  0.457157
# 53  north cave beck burst bank footpath bridge pap...  0.592032  0.395054
# 54                                      heartbreaking  0.818087  0.161149
# 55  main slip road beverley closed due flooding ho...  0.658541  0.328864
# 56  hopefully today rain cause u problem remember ...  0.540422  0.419639
# 57  startling statistic simon gallow development d...  0.772055  0.218688
#
#     Positive Sentiment  Label  RoBERTa_Prediction
# 0   0.038931  negative      0                   0
# 1   0.036588  negative      0                   0
# 2   0.013785  negative      0                   0
# 3   0.013036  negative      0                   0
# 4   0.017346  negative      0                   0
# 5   0.103279  negative      1                   1
# 6   0.005718  negative      1                   1
# 7   0.023321  negative      0                   0
# 8   0.012345  negative      0                   0
# 9   0.006652  negative      0                   0
# 10  0.025392  negative      0                   0
# 11  0.013795  negative      0                   0
# 12  0.018291  negative      1                   1
# 13  0.036006  negative      1                   0
# 14  0.002416  negative      0                   0
# 15  0.017886  negative      0                   0
# 16  0.020007  negative      0                   0
# 17  0.010814  negative      0                   0
# 18  0.029558  negative      0                   0
# 19  0.014374  negative      1                   1
# 20  0.006877  negative      0                   0
# 21  0.007924  negative      0                   0
# 22  0.077880  negative      0                   0
# 23  0.010447  negative      0                   0
# 24  0.011523  negative      0                   1
# 25  0.010464  negative      1                   1
# 26  0.002569  negative      1                   1
# 27  0.010248  negative      0                   0
# 28  0.014379  negative      0                   0
# 29  0.014666  negative      0                   0
# 30  0.058925  negative      0                   0
# 31  0.045219  negative      0                   0
# 32  0.026784  negative      0                   0
# 33  0.007510  negative      0                   1
# 34  0.016198  negative      0                   0
# 35  0.018238  negative      0                   1
# 36  0.009050  negative      0                   0
# 37  0.028548  negative      1                   1
# 38  0.014574  negative      0                   0
# 39  0.003251  negative      0                   0
# 40  0.018179  negative      0                   0
# 41  0.064697  negative      0                   0
# 42  0.035647  negative      0                   0
# 43  0.061219  negative      0                   0
# 44  0.011330  negative      0                   0
# 45  0.003528  negative      0                   0
# 46  0.154377  negative      0                   0
# 47  0.021675  negative      1                   1
# 48  0.016683  negative      1                   1
# 49  0.008699  negative      0                   0
# 50  0.025815  negative      0                   0
# 51  0.002236  negative      0                   0
# 52  0.014367  negative      0                   0
# 53  0.012914  negative      1                   1
# 54  0.020764  negative      0                   0
# 55  0.012595  negative      1                   1
# 56  0.039939  negative      0                   0
# 57  0.009258  negative      0                   0

# %%
new_df['RoBERTa_Prediction'].value_counts()
# Out:
# RoBERTa_Prediction
# 0    44
# 1    14
# Name: count, dtype: int64

# %%
new_df['Label'].value_counts()
# Out:
# Label
# 0    46
# 1    12
# Name: count, dtype: int64

# %%
# Calculating metrics
accuracy = accuracy_score(new_df['Label'], new_df['RoBERTa_Prediction'])
precision = precision_score(new_df['Label'], new_df['RoBERTa_Prediction'])
recall = recall_score(new_df['Label'], new_df['RoBERTa_Prediction'])
f1 = f1_score(new_df['Label'], new_df['RoBERTa_Prediction'])
roc_auc = roc_auc_score(new_df['Label'], new_df['RoBERTa_Prediction'])

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print(f"AUC-ROC: {roc_auc}")
# Out:
# Accuracy: 0.9310344827586207
# Precision: 0.7857142857142857
# Recall: 0.9166666666666666
# F1 Score: 0.8461538461538461
# AUC-ROC: 0.9257246376811593

# %%
# Creating a confusion matrix
conf_matrix = confusion_matrix(new_df['Label'], new_df['RoBERTa_Prediction'])

# Extracting TP, TN, FP, FN from the confusion matrix
TP = conf_matrix[1, 1]
TN = conf_matrix[0, 0]
FP = conf_matrix[0, 1]
FN = conf_matrix[1, 0]

# Calculating the number of wrong predictions
wrong_predictions = FP + FN


print(f"Number of wrong predictions: {wrong_predictions}")
# Out:
# Number of wrong predictions: 4

# %%
# Sample list of sentences
sentences = ["Had a wonderful time in hull today","there is a fire in the south street we need the your assistance @HumbersideFire", "The kids are lighting fireworks in pearson park it is really dangerous", "I see smoke coming from the paragon station", "Some teenager are jumping of the bridge into the water","There is no incident in the beverly road"]

# Tokenizing the list of sentences
inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt').to('cuda')

# Forward pass through the model
outputs = model(**inputs)

# Applying softmax to get predictions
predictions = torch.nn.functional.softmax(outputs.logits, dim=-1)

# Converting predictions to numpy array
predictions = predictions.cpu().detach().numpy()

# Getting the predicted labels
predicted_labels = [np.argmax(pred) for pred in predictions]

# Getting the corresponding probabilities
probs = [pred[label] for pred, label in zip(predictions, predicted_labels)]


for sentence, label, prob in zip(sentences, predicted_labels, probs):
    print(f"Sentence: {sentence}")
    print(f"Predicted Label: {label}")
    print(f"Probability: {prob:.4f}")
    print()
# Out:
# Sentence: Had a wonderful time in hull today
# Predicted Label: 0
# Probability: 0.9960
#
# Sentence: there is a fire in the south street we need the your assistance @HumbersideFire
# Predicted Label: 1
# Probability: 0.9957
#
# Sentence: The kids are lighting fireworks in pearson park it is really dangerous
# Predicted Label: 1
# Probability: 0.9976
#
# Sentence: I see smoke coming from the paragon station
# Predicted Label: 1
# Probability: 0.9989
#
# Sentence: Some teenager are jumping of the bridge into the water
# Predicted Label: 1
# Probability: 0.9652
#
# Sentence: There is no incident in the beverly road
# Predicted Label: 1
# Probability: 0.9873
