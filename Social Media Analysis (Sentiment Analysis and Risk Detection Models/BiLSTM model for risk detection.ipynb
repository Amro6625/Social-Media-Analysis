# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Bidirectional, LSTM, Dense, Dropout, Concatenate
import pickle
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Out:
# WARNING:tensorflow:From C:\Users\Amro\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Loading the Excel file
df = pd.read_excel('negative_sentiments.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User           209 non-null    object
#  1   Tweet          209 non-null    object
#  2   Cleaned_Tweet  209 non-null    object
#  3   Negative       209 non-null    float64
#  4   Neutral        209 non-null    float64
#  5   Positive       209 non-null    float64
#  6   Sentiment      209 non-null    object
#  7   Label          151 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 13.2+ KB

# %%
# Separating labeled and unlabeled data
predict_df = df[df['Label'].isna()]
train_df = df.dropna(subset=['Label'])

# %%
# Tokenizing and prepare data for training
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_df['Cleaned_Tweet'])
vocab_size = len(tokenizer.word_index) + 1

# %%
# Tokenize unigrams
X_unigrams = tokenizer.texts_to_sequences(train_df['Cleaned_Tweet'])
X_unigrams = pad_sequences(X_unigrams, padding='post', truncating='post', maxlen=128)

# Creating bigrams 
X_bigrams = []
for tweet_tokens in zip(train_df['Cleaned_Tweet'].str.split(), train_df['Cleaned_Tweet'].str.split().shift(-1)):
    bigram_sequence = tokenizer.texts_to_sequences([' '.join(map(str, tweet_tokens))])
    X_bigrams.extend(bigram_sequence)

X_bigrams = pad_sequences(X_bigrams, padding='post', truncating='post', maxlen=128)

# Create trigrams
X_trigrams = []
for tweet_tokens in zip(train_df['Cleaned_Tweet'].str.split(), train_df['Cleaned_Tweet'].str.split().shift(-1), train_df['Cleaned_Tweet'].str.split().shift(-2)):
    trigram_sequence = tokenizer.texts_to_sequences([' '.join(map(str, tweet_tokens))])
    X_trigrams.extend(trigram_sequence)

X_trigrams = pad_sequences(X_trigrams, padding='post', truncating='post', maxlen=128)

# Concatenating unigrams, bigrams, and trigrams
X_combined = np.concatenate([X_unigrams, X_bigrams, X_trigrams], axis=1)

y = train_df['Label'].values

# Splitting the training data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_combined, y, test_size=0.1, random_state=42)

# %%
# Defining the BiLSTM model with three layers and dropout
embedding_dim = 50

inputs = Input(shape=(384,))  
embedding_layer = Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=384)(inputs)
bi_lstm_1 = Bidirectional(LSTM(64, return_sequences=True))(embedding_layer)
dropout_1 = Dropout(0.5)(bi_lstm_1)
bi_lstm_2 = Bidirectional(LSTM(64, return_sequences=True))(dropout_1)
dropout_2 = Dropout(0.5)(bi_lstm_2)
bi_lstm_3 = Bidirectional(LSTM(64))(dropout_2)
dropout_final = Dropout(0.5)(bi_lstm_3)
outputs = Dense(1, activation='sigmoid')(dropout_final)

# Compiling the model
model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


# Training the BiLSTM model with early stopping
epochs = 25
batch_size = 8

history = model.fit(
    X_train, y_train,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(X_val, y_val)
   
)
# Out:
# WARNING:tensorflow:From C:\Users\Amro\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Amro\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/25
# WARNING:tensorflow:From C:\Users\Amro\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Amro\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 17/17 [==============================] - 12s 294ms/step - loss: 0.5864 - accuracy: 0.7630 - val_loss: 0.3660 - val_accuracy: 0.9375
# Epoch 2/25
# 17/17 [==============================] - 3s 198ms/step - loss: 0.5478 - accuracy: 0.7630 - val_loss: 0.2708 - val_accuracy: 0.9375
# Epoch 3/25
# 17/17 [==============================] - 3s 199ms/step - loss: 0.4918 - accuracy: 0.7778 - val_loss: 0.2039 - val_accuracy: 0.9375
# Epoch 4/25
# 17/17 [==============================] - 3s 197ms/step - loss: 0.3480 - accuracy: 0.8741 - val_loss: 0.2740 - val_accuracy: 0.8750
# Epoch 5/25
# 17/17 [==============================] - 3s 198ms/step - loss: 0.1261 - accuracy: 0.9704 - val_loss: 0.6192 - val_accuracy: 0.6875
# Epoch 6/25
# 17/17 [==============================] - 3s 198ms/step - loss: 0.0556 - accuracy: 0.9852 - val_loss: 0.3151 - val_accuracy: 0.9375
# Epoch 7/25
# 17/17 [==============================] - 3s 197ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 1.9215 - val_accuracy: 0.6875
# Epoch 8/25
# 17/17 [==============================] - 3s 196ms/step - loss: 0.0860 - accuracy: 0.9852 - val_loss: 0.7608 - val_accuracy: 0.8125
# Epoch 9/25
# 17/17 [==============================] - 3s 197ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.6699 - val_accuracy: 0.8750
# Epoch 10/25
# 17/17 [==============================] - 3s 196ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.7359 - val_accuracy: 0.8750
# Epoch 11/25
# 17/17 [==============================] - 3s 196ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.7778 - val_accuracy: 0.8750
# Epoch 12/25
# 17/17 [==============================] - 3s 197ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.8085 - val_accuracy: 0.8750
# Epoch 13/25
# 17/17 [==============================] - 3s 195ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.8342 - val_accuracy: 0.8750
# Epoch 14/25
# 17/17 [==============================] - 3s 195ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.8577 - val_accuracy: 0.8750
# Epoch 15/25
# 17/17 [==============================] - 3s 196ms/step - loss: 9.9032e-04 - accuracy: 1.0000 - val_loss: 0.8787 - val_accuracy: 0.8750
# Epoch 16/25
# 17/17 [==============================] - 3s 195ms/step - loss: 8.1117e-04 - accuracy: 1.0000 - val_loss: 0.8971 - val_accuracy: 0.8750
# Epoch 17/25
# 17/17 [==============================] - 3s 194ms/step - loss: 6.1613e-04 - accuracy: 1.0000 - val_loss: 0.9130 - val_accuracy: 0.8750
# Epoch 18/25
# 17/17 [==============================] - 3s 195ms/step - loss: 6.0750e-04 - accuracy: 1.0000 - val_loss: 0.9275 - val_accuracy: 0.8750
# Epoch 19/25
# 17/17 [==============================] - 3s 194ms/step - loss: 4.9057e-04 - accuracy: 1.0000 - val_loss: 0.9400 - val_accuracy: 0.8750
# Epoch 20/25
# 17/17 [==============================] - 3s 194ms/step - loss: 6.5669e-04 - accuracy: 1.0000 - val_loss: 0.9546 - val_accuracy: 0.8750
# Epoch 21/25
# 17/17 [==============================] - 3s 196ms/step - loss: 4.6393e-04 - accuracy: 1.0000 - val_loss: 0.9684 - val_accuracy: 0.8750
# Epoch 22/25
# 17/17 [==============================] - 3s 194ms/step - loss: 4.4416e-04 - accuracy: 1.0000 - val_loss: 0.9795 - val_accuracy: 0.8750
# Epoch 23/25
# 17/17 [==============================] - 3s 195ms/step - loss: 3.3243e-04 - accuracy: 1.0000 - val_loss: 0.9896 - val_accuracy: 0.8750
# Epoch 24/25
# 17/17 [==============================] - 3s 195ms/step - loss: 3.8169e-04 - accuracy: 1.0000 - val_loss: 0.9996 - val_accuracy: 0.8750
# Epoch 25/25
# 17/17 [==============================] - 3s 194ms/step - loss: 3.8783e-04 - accuracy: 1.0000 - val_loss: 1.0105 - val_accuracy: 0.8750

# %% [markdown]
# # Tokenizing and prepare data for training
# tokenizer = Tokenizer()
# tokenizer.fit_on_texts(train_df['Cleaned_Tweet'])
# vocab_size = len(tokenizer.word_index) + 1
#
# X = tokenizer.texts_to_sequences(train_df['Cleaned_Tweet'])
# X = pad_sequences(X, padding='post', truncating='post', maxlen=128)
# y = train_df['Label'].values
#
# # Splitting the training data into train and validation sets
# X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# # Defining the BiLSTM model with three layers and dropout
# embedding_dim = 50
#
# inputs = Input(shape=(128,))
# embedding_layer = Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=128)(inputs)
# bi_lstm_1 = Bidirectional(LSTM(64, return_sequences=True))(embedding_layer)
# dropout_1 = Dropout(0.5)(bi_lstm_1)
# bi_lstm_2 = Bidirectional(LSTM(64, return_sequences=True))(dropout_1)
# dropout_2 = Dropout(0.5)(bi_lstm_2)
# bi_lstm_3 = Bidirectional(LSTM(64))(dropout_2)
# dropout_final = Dropout(0.5)(bi_lstm_3)
# outputs = Dense(1, activation='sigmoid')(dropout_final)
#
# # Compiling the model
# model = Model(inputs=inputs, outputs=outputs)
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#
# # Defining early stopping criteria
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
#
# # Training the BiLSTM model with early stopping
# epochs = 50
# batch_size = 8
#
# history = model.fit(
#     X_train, y_train,
#     epochs=epochs,
#     batch_size=batch_size,
#     validation_data=(X_val, y_val),
#     callbacks=[early_stopping]
# )

# %%
# Validation
val_preds = model.predict(X_val).flatten()
val_preds_binary = (val_preds > 0.5).astype(int)

# Print classification report
print(classification_report(y_val, val_preds_binary))
# Out:
# 1/1 [==============================] - 1s 1s/step
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.93      0.93        15
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           0.88        16
#    macro avg       0.47      0.47      0.47        16
# weighted avg       0.88      0.88      0.88        16

# %%
# Calculating Mean Squared Error (MSE)
mse = mean_squared_error(y_val, val_preds)
print(f"Mean Squared Error (MSE): {mse:.4f}")

# Calculating Mean Absolute Error (MAE)
mae = mean_absolute_error(y_val, val_preds)
print(f"Mean Absolute Error (MAE): {mae:.4f}")

# Calculating R-squared (R2) score
r2 = r2_score(y_val, val_preds)
print(f"R-squared (R2) Score: {r2:.4f}")
# Out:
# Mean Squared Error (MSE): 0.1249
# Mean Absolute Error (MAE): 0.1250
# R-squared (R2) Score: -1.1309

# %%
# Prediction on unlabeled data
unlabeled_texts = predict_df['Cleaned_Tweet'].values
X_unlabeled = tokenizer.texts_to_sequences(unlabeled_texts)
X_unlabeled = pad_sequences(X_unlabeled, padding='post', truncating='post', maxlen=128)

unlabeled_preds = model.predict(X_unlabeled).flatten()
unlabeled_preds_binary = (unlabeled_preds > 0.5).astype(int)

# Add predicted labels to the predict_df DataFrame
predict_df['Predicted_Label'] = unlabeled_preds_binary

# Print each tweet and the predicted label
for index, row in predict_df.iterrows():
    print(f"Tweet: {row['Cleaned_Tweet']}, Predicted Label: {row['Predicted_Label']}")
# Out:
# 2/2 [==============================] - 1s 32ms/step
# Tweet: bagger amazed knew walking football result yesterday clearly doesnt twitter explained followed, Predicted Label: 0
# Tweet: blimey mick old dog, Predicted Label: 0
# Tweet: wondered rd right obvs due play rare midweek game wasnt good enough saturday league l put bat pls send regard, Predicted Label: 1
# Tweet: guy tweet date wrong think, Predicted Label: 0
# Tweet: biggest crime issue north east lincolnshire tell u view survey open th august, Predicted Label: 0
# Tweet: spent week tackling fire hatfield moor desperately need help stop fire beautiful site like especially hot dry day like today bbqs cigarette rubbish yes life, Predicted Label: 1
# Tweet: attended incident tonight binbrook way group youth used petrol start fire tree bushed areagiven dry condition late incredibly dangerous thank attending averting issue, Predicted Label: 0
# Tweet: fire safety message today people easy overload electrical socket result house fire check advice dont call, Predicted Label: 0
# Tweet: warm outside doesnt mean warm underwater cold water shock kill open water swimming kill stay open water reduce pressure emergency service, Predicted Label: 0
# Tweet: unfortunately im going say noour street would fact burn help could get, Predicted Label: 0
# Tweet: didnt think would put outfit last incident, Predicted Label: 0
# Tweet: sliding batpole must fraught pain danger wolfy, Predicted Label: 0
# Tweet: wholetime oncall crew appliance misterton amp appliance epworth attended commercial building fire carr lane gainsborough severe fire damage compressor room content, Predicted Label: 1
# Tweet: glad one injured back work week realise mad lincolnshire driver one car passed near wragby morning must mph mph road wonder red sign telling u death number lincs road, Predicted Label: 0
# Tweet: lazy gutterpress journalism embarrassment worst encourages glorifies much violence amp intolerance see growing society hack journalist lost pride profession worst u, Predicted Label: 0
# Tweet: well said chris sorry medium making job difficult, Predicted Label: 0
# Tweet: day sequestration capacity lost c acre sssi national nature reserve least great british spudsbbqd amp chip anyonedevastating amp absolutely unnecessary risk, Predicted Label: 0
# Tweet: limit sympathy im afraid, Predicted Label: 0
# Tweet: missed wall end inch look, Predicted Label: 0
# Tweet: grazers would eaten low braches still place like chatsworth park people messed around humberhead level order charles diverting river dry area agriculture resulting flooding elsewhere place like fishlake, Predicted Label: 0
# Tweet: today may day amp day use helicopter show seriousness incident absolutely devastating first casualty, Predicted Label: 0
# Tweet: hi sorry wondered letter posted mum letter box yesterday fake doesnt seem right thats cheer, Predicted Label: 0
# Tweet: sooo much going present avoidable sadly helicopter firefighting support available need stay safe team, Predicted Label: 0
# Tweet: five family life turned upside arsonist hull inferno took everything asked could help food parcel course continue help wherever, Predicted Label: 0
# Tweet: top mark sky lantern start fire deadly farm animal wildlife please stick clapping thursday pm thanks, Predicted Label: 1
# Tweet: please avoid using showing appreciation nh amp keyworkers sky lantern danger wildlife environment huge fire risk amp could tie valuable resource, Predicted Label: 1
# Tweet: please please please please dont set sky lantern dangerous kill wildlife set fire ridiculous, Predicted Label: 1
# Tweet: emergency service enough dealing earth lantern show support could potentially cause service work mention danger wildlife, Predicted Label: 0
# Tweet: also dedicated email cant use phone deaf non verbal etc, Predicted Label: 0
# Tweet: thank assisting insp hutton evening bridlington pigeon trapped netting pigeon tangled quite severely caused serious injury, Predicted Label: 0
# Tweet: nose know fooling etta, Predicted Label: 1
# Tweet: cpad fire station back running ive replaced unfortunately nobody make cup tea, Predicted Label: 0
# Tweet: presumably dont agree science dredging would made difference situation, Predicted Label: 0
# Tweet: dredging sediment crap river start, Predicted Label: 0
# Tweet: public meeting taking place snaith primary school key feedback resident far environment agency didnt listen well local knowledge land ea say taking onboard, Predicted Label: 0
# Tweet: litre flood water pumped away every minute still devastating community amp amp many working hard assist, Predicted Label: 0
# Tweet: rain might stopped multi agency response affected community around snaith hasnt assisted colleague country alleviate floodwaters, Predicted Label: 0
# Tweet: medium duty morning awful see home flooded despite best effort manage exceptional r aire, Predicted Label: 0
# Tweet: winner worst joke year, Predicted Label: 0
# Tweet: apparently fake grown adult pretending he posted facebook saying k bank fool dont know believe anymore fake sick, Predicted Label: 0
# Tweet: people refuse listen act warning obvious sign even without road sign danger clear see drive flood water x male lead safety support, Predicted Label: 0
# Tweet: lucky get, Predicted Label: 1
# Tweet: today trip around reserve found call could without human recklessness ignorance human disgust, Predicted Label: 0
# Tweet: nice thing around ward east west marsh problem yarborough ward never seem get treatment several burglary dn area last week fly tipping dog muck poor parking speeding traffic, Predicted Label: 0
# Tweet: emergency worker assaulted must full extent law behind bring perpetrator justice nfa cannot option, Predicted Label: 0
# Tweet: general manager lincolnshire sue cousland morning alongside police fire colleague campaign assault staff emergency service unacceptable, Predicted Label: 1
# Tweet: devastating news sorry rob everyone involved buisness thankyou hard working emergency service, Predicted Label: 0
# Tweet: news huge vegetable oil fire east yorkshire pic, Predicted Label: 0
# Tweet: closed eastbound barnetby top brocklesby interchange tonight deal accident one car involved appears facing wrong way central reservation long queue westbound police closed lane past scene, Predicted Label: 1
# Tweet: looked terrible aswell fair think snaith one many year ago reallocated lgv training yea rapier loved essex know didnt hang around, Predicted Label: 0
# Tweet: volvos terrible two lgv training slow get mph tail wind downhill rapier otherhand, Predicted Label: 0
# Tweet: employee justin morris stalker harasser instigator hate false accuser psychopath fascist criminal hatecrime participant amp look like pedophile click pic, Predicted Label: 0
# Tweet: making child aware domestic abuse, Predicted Label: 0
# Tweet: north cave beck burst bank footpath bridge paper mill house dangerous slat become loose fire service cordened, Predicted Label: 1
# Tweet: heartbreaking, Predicted Label: 0
# Tweet: main slip road beverley closed due flooding hour ago tough drive home tonight main route around town struggling severe surface water, Predicted Label: 1
# Tweet: hopefully today rain cause u problem remember garden flood inconvenient unless property threatened flooding please dont call check weather forecast warning stay, Predicted Label: 0
# Tweet: startling statistic simon gallow development director year away gender equality woman likely suffer injury car accident due test dummy based average men, Predicted Label: 0
# C:\Users\Amro\AppData\Local\Temp\ipykernel_320\804632990.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predict_df['Predicted_Label'] = unlabeled_preds_binary

# %%
# Input text
text = "there is a fire in south street"

# Tokenize the input text
input_sequence = tokenizer.texts_to_sequences([text])
input_sequence = pad_sequences(input_sequence, padding='post', truncating='post', maxlen=128)

# Make a prediction
prediction = model.predict(input_sequence).flatten()[0]
predicted_label = int(prediction > 0.5)

# Display the prediction
print(f"Predicted Label for Input Text: {predicted_label}")
# Out:
# 1/1 [==============================] - 0s 26ms/step
# Predicted Label for Input Text: 1

# %%
predict_df['Predicted_Label'].value_counts()
# Out:
# Predicted_Label
# 0    46
# 1    12
# Name: count, dtype: int64

# %%
predict_df
# Out:
#                                             User  \
# 151                                          Bev
# 152                                      Nigel 💙
# 153                                      Nigel 💙
# 154                           Iain Joseph Gorry*
# 155              North East Lincolnshire Council
# 156                         South Yorkshire Fire
# 157  Humberside Police - North East Lincolnshire
# 158                           Safer Roads Humber
# 159                          North Lincs Council
# 160                                    DC_LK1989
# 161                        Alan Clark 💙 🇺🇦 🇪🇺 🇬🇧
# 162                  Park Street Performing Arts
# 163                 Lincolnshire Fire and Rescue
# 164                                      russell
# 165                                    Mark Webb
# 166                             James Mitchinson
# 167                                  Bog-trotter
# 168                                          CSB
# 169                                   Rob Buckle
# 170                      Sheffield Environmental
# 171                                  Bog-trotter
# 172                                 chris spavin
# 173                                 Guy Hitchins
# 174                                Hull 4 Heroes
# 175                               Farmers Weekly
# 176                          PCSO Darren Bainton
# 177                                  Dave Nassau
# 178                                     Debs B 🌱
# 179     Elephant in The Room Disability Services
# 180                              RSPCA Frontline
# 181                                Howard Davies
# 182                                        Jon T
# 183                           Jazzmariner ⚫️⚪️😁👏
# 184                                Lankyshirelad
# 185                               Phillip Norton
# 186                                   Kev Taylor
# 187                                Phil Shillito
# 188                              Adam Tunningley
# 189                                          CDW
# 190                                mollie brooks
# 191                                 Andy Creasey
# 192                               Peter Anderson
# 193          Nickynoo/Aquanaught/conservationist
# 194                                 Kevin Childs
# 195                                         Nick
# 196    East Midlands Ambulance Service NHS Trust
# 197                                 Gareth smith
# 198   Greatest Hits Radio York & North Yorkshire
# 199                               Phillip Norton
# 200                        UK Fire Rescue Photos
# 201                                       Stew B
# 202               Adam Craig, PB (Xe/Xer/Xerxes)
# 203                         St Richard's Academy
# 204                            Wolds View Garage
# 205                           Susan Chandler 💙🇺🇦
# 206                              caroline bilton
# 207                              Hull Flood Risk
# 208                    Miriam Heppell 💙MSc FCIPD
#
#                                                  Tweet  \
# 151  @GyAncient @nige_gallop @CCLeeFreeman @Cleeccs...
# 152  @GyAncient @BevskiMids @CCLeeFreeman @Cleeccsc...
# 153  @BevskiMids @CCLeeFreeman @Cleeccsc @Humberbea...
# 154  @Cleeccsc @JoRobbo68 @Humberbeat @HumbersideFi...
# 155  What are the biggest crime issues in North Eas...
# 156  We spent weeks tackling a fire on Hatfield Moo...
# 157  #Grimsby #Willows Attended an incident tonight...
# 158  A fire safety message today. With more people ...
# 159  Just because it's warm outside, it doesn't mea...
# 160  Unfortunately I’m going to say no...our street...
# 161  @Fionamills1 @Humber_01 @HareWolfy @LouiseWrit...
# 162  @HareWolfy @Humber_01 @Fionamills1 @LouiseWrit...
# 163  13:26 1/2 Wholetime and On-Call Crew from @Gai...
# 164  @HumbersideFire Glad no one injured 👍 i have b...
# 165  @CFOBlacksell @HumbersideFire @Humberbeat This...
# 166  @CFOBlacksell @HumbersideFire @Humberbeat Well...
# 167  @Marktur03393381 @SYFR @WYFRS @LancashireFRS @...
# 168  @PCSODarrenB @HumbersideFire Over the limit? N...
# 169  @sunkfarmer @PCSODarrenB @HumbersideFire Misse...
# 170  @BryonyHolroyd @AndyMbirder @4peatssake2 @Wint...
# 171  @paulbrear @HumbersideFire @SYFR Today (30 May...
# 172  @HumbersideFire Hi sorry to both you. Just won...
# 173  @HumbersideFire @SYFR Sooo much of this going ...
# 174  Five families had their lives turned upside do...
# 175  Top marks @HumbersideFire 👍 Sky lanterns start...
# 176  Please avoid using #SkyLanterns when showing y...
# 177  @Dr_Dan_1 @HumbersideFire @ChrisGPackham @Bell...
# 178  @BBCLookNorth @HumbersideFire Emergency servic...
# 179  @CEXHCC @21_hardy @Hullccnews @NHSHullCCG @NHS...
# 180  Thank you to @HumbersideFire for assisting Ins...
# 181  @shooter724 @Humberbeat @HumbersideFire The no...
# 182  The CPAD at #Patrington fire station is now ba...
# 183  @JKH62 @EnvAgencyYNE @johncurtinEA @EnvAgency ...
# 184  @EnvAgencyYNE @johncurtinEA @EnvAgency @TobyWi...
# 185  A public meeting is taking place at Snaith Pri...
# 186  250,000 litres of flood waters pumped away eve...
# 187  The rain might have stopped but the multi agen...
# 188  Media duties in #Snaith for me this morning. A...
# 189  @HumbersideFire And the winners of the worst j...
# 190  @EllieSimmonds1 @HumbersideFire Apparently thi...
# 191  Again people refuse the listen or act on warni...
# 192  @krispygreen84 @HumbersideFire @officialgtfc I...
# 193  Today after a trip around the reserve I found ...
# 194  @NELCouncil @HumberbeatNEL @HumbersideFire Be ...
# 195  @CCLeeFreeman @Humberbeat @HumbersideFire @EMA...
# 196  Our General Manager for Lincolnshire, Sue Cous...
# 197  @BrocklesbyLtd @HumbersideFire Devastating new...
# 198  NEWS - Huge vegetable oil fire in East Yorkshi...
# 199  The A180 is closed eastbound from Barnetby Top...
# 200  @Ball01B @HumbersideFire They looked terrible ...
# 201  @fireenguk @HumbersideFire Those Volvos were t...
# 202  @UniofHull @HullPoliticsDep employee, Justin M...
# 203  Making children more aware about domestic abus...
# 204  @HumbersideFire North Cave beck had burst it's...
# 205  @CoultishNick @21_hardy @HumberbeatRoads @Radi...
# 206  Main slip road off A1079 into Beverley closed ...
# 207  Hopefully today's rain will not cause us more ...
# 208  Startling statistics from Simon Gallow, Develo...
#
#                                          Cleaned_Tweet  Negative   Neutral  \
# 151  bagger amazed knew walking football result yes...  0.519025  0.442044
# 152                                blimey mick old dog  0.677478  0.285934
# 153  wondered rd right obvs due play rare midweek g...  0.763980  0.222234
# 154                         guy tweet date wrong think  0.664363  0.322601
# 155  biggest crime issue north east lincolnshire te...  0.662119  0.320535
# 156  spent week tackling fire hatfield moor despera...  0.560314  0.336407
# 157  attended incident tonight binbrook way group y...  0.889538  0.104743
# 158  fire safety message today people easy overload...  0.514286  0.462393
# 159  warm outside doesnt mean warm underwater cold ...  0.698401  0.289254
# 160  unfortunately im going say noour street would ...  0.875694  0.117654
# 161         didnt think would put outfit last incident  0.504043  0.470565
# 162     sliding batpole must fraught pain danger wolfy  0.644666  0.341539
# 163  wholetime oncall crew appliance misterton amp ...  0.538386  0.443323
# 164  glad one injured back work week realise mad li...  0.590768  0.373226
# 165  lazy gutterpress journalism embarrassment wors...  0.962897  0.034687
# 166  well said chris sorry medium making job difficult  0.747294  0.234820
# 167  day sequestration capacity lost c acre sssi na...  0.723867  0.256126
# 168                           limit sympathy im afraid  0.808927  0.180259
# 169                          missed wall end inch look  0.510658  0.459784
# 170  grazers would eaten low braches still place li...  0.612657  0.372969
# 171  today may day amp day use helicopter show seri...  0.852878  0.140245
# 172  hi sorry wondered letter posted mum letter box...  0.871667  0.120409
# 173  sooo much going present avoidable sadly helico...  0.521803  0.400316
# 174  five family life turned upside arsonist hull i...  0.766391  0.223161
# 175  top mark sky lantern start fire deadly farm an...  0.744505  0.243972
# 176  please avoid using showing appreciation nh amp...  0.772356  0.217180
# 177  please please please please dont set sky lante...  0.963210  0.034221
# 178  emergency service enough dealing earth lantern...  0.686192  0.303560
# 179  also dedicated email cant use phone deaf non v...  0.709626  0.275995
# 180  thank assisting insp hutton evening bridlingto...  0.771515  0.213819
# 181                             nose know fooling etta  0.486248  0.454826
# 182  cpad fire station back running ive replaced un...  0.531859  0.422922
# 183  presumably dont agree science dredging would m...  0.492322  0.480894
# 184                 dredging sediment crap river start  0.892963  0.099527
# 185  public meeting taking place snaith primary sch...  0.593255  0.390547
# 186  litre flood water pumped away every minute sti...  0.792955  0.188807
# 187  rain might stopped multi agency response affec...  0.737688  0.253263
# 188  medium duty morning awful see home flooded des...  0.742428  0.229025
# 189                             winner worst joke year  0.918154  0.067271
# 190  apparently fake grown adult pretending he post...  0.933319  0.063430
# 191  people refuse listen act warning obvious sign ...  0.629452  0.352369
# 192                                          lucky get  0.648431  0.286872
# 193  today trip around reserve found call could wit...  0.536601  0.427751
# 194  nice thing around ward east west marsh problem...  0.637865  0.300916
# 195  emergency worker assaulted must full extent la...  0.636483  0.352187
# 196  general manager lincolnshire sue cousland morn...  0.912067  0.084404
# 197  devastating news sorry rob everyone involved b...  0.497504  0.348119
# 198    news huge vegetable oil fire east yorkshire pic  0.544575  0.433751
# 199  closed eastbound barnetby top brocklesby inter...  0.503025  0.480293
# 200  looked terrible aswell fair think snaith one m...  0.856355  0.134946
# 201  volvos terrible two lgv training slow get mph ...  0.617543  0.356642
# 202  employee justin morris stalker harasser instig...  0.963156  0.034609
# 203                  making child aware domestic abuse  0.528476  0.457157
# 204  north cave beck burst bank footpath bridge pap...  0.592032  0.395054
# 205                                      heartbreaking  0.818087  0.161149
# 206  main slip road beverley closed due flooding ho...  0.658541  0.328864
# 207  hopefully today rain cause u problem remember ...  0.540422  0.419639
# 208  startling statistic simon gallow development d...  0.772055  0.218688
#
#      Positive Sentiment  Label  Predicted_Label
# 151  0.038931  negative    NaN                0
# 152  0.036588  negative    NaN                0
# 153  0.013785  negative    NaN                1
# 154  0.013036  negative    NaN                0
# 155  0.017346  negative    NaN                0
# 156  0.103279  negative    NaN                1
# 157  0.005718  negative    NaN                0
# 158  0.023321  negative    NaN                0
# 159  0.012345  negative    NaN                0
# 160  0.006652  negative    NaN                0
# 161  0.025392  negative    NaN                0
# 162  0.013795  negative    NaN                0
# 163  0.018291  negative    NaN                1
# 164  0.036006  negative    NaN                0
# 165  0.002416  negative    NaN                0
# 166  0.017886  negative    NaN                0
# 167  0.020007  negative    NaN                0
# 168  0.010814  negative    NaN                0
# 169  0.029558  negative    NaN                0
# 170  0.014374  negative    NaN                0
# 171  0.006877  negative    NaN                0
# 172  0.007924  negative    NaN                0
# 173  0.077880  negative    NaN                0
# 174  0.010447  negative    NaN                0
# 175  0.011523  negative    NaN                1
# 176  0.010464  negative    NaN                1
# 177  0.002569  negative    NaN                1
# 178  0.010248  negative    NaN                0
# 179  0.014379  negative    NaN                0
# 180  0.014666  negative    NaN                0
# 181  0.058925  negative    NaN                1
# 182  0.045219  negative    NaN                0
# 183  0.026784  negative    NaN                0
# 184  0.007510  negative    NaN                0
# 185  0.016198  negative    NaN                0
# 186  0.018238  negative    NaN                0
# 187  0.009050  negative    NaN                0
# 188  0.028548  negative    NaN                0
# 189  0.014574  negative    NaN                0
# 190  0.003251  negative    NaN                0
# 191  0.018179  negative    NaN                0
# 192  0.064697  negative    NaN                1
# 193  0.035647  negative    NaN                0
# 194  0.061219  negative    NaN                0
# 195  0.011330  negative    NaN                0
# 196  0.003528  negative    NaN                1
# 197  0.154377  negative    NaN                0
# 198  0.021675  negative    NaN                0
# 199  0.016683  negative    NaN                1
# 200  0.008699  negative    NaN                0
# 201  0.025815  negative    NaN                0
# 202  0.002236  negative    NaN                0
# 203  0.014367  negative    NaN                0
# 204  0.012914  negative    NaN                1
# 205  0.020764  negative    NaN                0
# 206  0.012595  negative    NaN                1
# 207  0.039939  negative    NaN                0
# 208  0.009258  negative    NaN                0

# %%
# Sample list of sentences
sentences = ["Had a wonderful time in hull today","there is a fire in the south street we need the your assistance @HumbersideFire", "The kids are lighting fireworks in pearson park it is really dangerous", "I see smoke coming from the paragon station", "Some teenager are jumping of the bridge into the water","There is no incident in the beverly road"]
# Tokenize the list of sentences
input_sequences = tokenizer.texts_to_sequences(sentences)
input_sequences = pad_sequences(input_sequences, padding='post', truncating='post', maxlen=128)

# Make predictions for the input sequences
predictions = model.predict(input_sequences).flatten()

# Apply a threshold (e.g., 0.5) to get binary predictions
predicted_labels = (predictions > 0.5).astype(int)

# Print results
for sentence, label, prob in zip(sentences, predicted_labels, predictions):
    print(f"Sentence: {sentence}")
    print(f"Predicted Label: {label}")
    print(f"Probability: {prob:.4f}")
    print()
# Out:
# 1/1 [==============================] - 0s 139ms/step
# Sentence: Had a wonderful time in hull today
# Predicted Label: 0
# Probability: 0.0001
#
# Sentence: there is a fire in the south street we need the your assistance @HumbersideFire
# Predicted Label: 1
# Probability: 0.9995
#
# Sentence: The kids are lighting fireworks in pearson park it is really dangerous
# Predicted Label: 1
# Probability: 0.9982
#
# Sentence: I see smoke coming from the paragon station
# Predicted Label: 1
# Probability: 0.9995
#
# Sentence: Some teenager are jumping of the bridge into the water
# Predicted Label: 0
# Probability: 0.0001
#
# Sentence: There is no incident in the beverly road
# Predicted Label: 0
# Probability: 0.0001

# %% [markdown]
# # Saving the model
# model.save('BiLSTM_model.h5')
# print("Model saved successfully.")

# %% [markdown]
# # Save the tokenizer
# with open('BiLSTM_tokenizer.pickle', 'wb') as handle:
#     pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
# print("Tokenizer saved successfully.")

# %%
import os

# %%
output_file_path = 'Labeled_Tweets.xlsx'
predict_df.to_excel(output_file_path, index=False)
